# %% [markdown]
# # Homework: Regression to the Mean

# %% [markdown]
# ### Excercises
#
# It is now your turn to do regression on a dataset. Consider $1000$ datapoints with random variables $x$ and $y$ both sampled from a normal (gaussian) distribution:
# $$ x,y \text{ ~ } \mathcal{N}(0,1)  $$
#
# Notice that the graph below looks like a blob, with no clear relationship between  $x$ and $y$. This leads intuitively to the idea that $x$ and $y$ are independent from each other. In this particualr case (not always true) this intuition is correct, $x$ and $y$ are mathematically independent variables.
#
# If we were to try to perform linear regression on this data (the <font style="color:red">red line</font>), we would find rather boring results:
# $$ y = 0 + 0 \cdot x = 0 $$
#
# This is due to the fact that $y$ has mean 0 and is independent of $x$. What do you think would happen if we did:
# $$ y-x = w_0 + w_1 \cdot x $$
#
# Is $y$ independent of $x$? Will the graph look like a blob? Will $y-x = 0 ?$ Lets find out!

# %%
# %pylab inline
# %pylab magic function is entered at the IPython prompt, it triggers the import of various modules within Matplotlib
from scipy import *
from numpy.linalg import norm
from math import sqrt,sin,cos
import pandas as pd
import numpy as np
from numpy import arange,array,ones,linalg
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/nicholaseverette/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['cumprod', 'sort_complex', 'isposinf', 'getbufsize', 'f', 'iterable', 'conj', 'nanprod', 'iscomplex', 'putmask', 'extract', '__version__', 'real_if_close', 'amax', 'bincount', 'imag', 'signbit', 'isfinite', 'polymul', 'nanmedian', 'less_equal', 'bartlett', 'apply_over_axes', 'logical_and', 'product', 'ix_', 'nan_to_num', 'outer', 'geterrobj', 'tril_indices_from', 'irr', 'count_nonzero', 'nanmax', 'pad', 'fromfunction', 'arcsin', 'true_divide', 'i0', 'recfromcsv', 'datetime_as_string', 'savetxt', 'tanh', 'fmax', 'safe_eval', 'histogramdd', 'logspace', 'histogram2d', 'log10', 'polyfit', 'disp', 'append', '_add_newdoc_ufunc', 'isin', 'printoptions', 'logical_xor', 'polyval', 'degrees', 'iscomplexobj', 'hamming', 'triu_indices', 'cov', 'rint', 'sinc', 'format_float_positional', 'shape', 'set_string_function', 'kaiser', 'bitwise_or', 'base_repr', 'shares_memory', 'einsum', 'seterrobj', 'nanmean', 'invert', 'arctan2', 'kron', 'ldexp', 'fmod', 'mean', 'ppmt', 'broadcast_to', 'arccosh', 'squeeze', 'average', 'sort', 'allclose', 'take', 'promote_types', 'subtract', 'fill_diagonal', 'byte_bounds', 'poly', 'cumsum', 'trapz', 'nanquantile', 'in1d', 'set_printoptions', 'rad2deg', 'nextafter', 'atleast_1d', 'matmul', 'left_shift', 'repeat', 'randn', 'inner', 'split', 'issubsctype', 'mod', 'divide', 'arccos', 'unravel_index', 'divmod', 'fromregex', 'not_equal', 'get_include', 'flatnonzero', 'mafromtxt', 'compare_chararrays', 'setbufsize', 'delete', 'digitize', 'nansum', 'sqrt', 'percentile', 'polyadd', 'indices', 'sign', 'obj2sctype', 'sum', 'cbrt', 'dot', 'ascontiguousarray', 'find_common_type', 'recfromtxt', 'asscalar', 'array_split', 'row_stack', 'compress', 'show_config', 'stack', 'remainder', 'nanvar', 'zeros_like', 'unique', 'frombuffer', 'apply_along_axis', 'select', 'array2string', 'reshape', 'array_str', 'logaddexp', 'frexp', 'tril_indices', 'hanning', 'sometrue', 'isneginf', 'intersect1d', 'loadtxt', 'nanstd', 'eye', 'insert', 'sinh', 'setdiff1d', 'alen', 'prod', 'full_like', 'linspace', 'reciprocal', 'isfortran', 'triu', 'corrcoef', 'unpackbits', 'trace', 'test', 'pmt', 'argpartition', 'positive', 'cumproduct', 'isinf', 'multiply', 'can_cast', 'sctype2char', 'std', 'arctanh', 'less', 'size', 'ipmt', 'fromstring', 'copysign', 'logical_not', 'bmat', 'swapaxes', 'may_share_memory', 'put_along_axis', 'nanmin', 'floor_divide', 'hstack', 'bitwise_xor', 'genfromtxt', 'loads', 'zeros', 'all', 'mintypecode', 'ifft', 'correlate', 'tile', 'nonzero', 'add', 'heaviside', 'npv', 'setxor1d', 'flip', 'histogram_bin_edges', 'typename', 'add_newdoc', 'alltrue', 'interp', 'pv', 'polyint', 'savez_compressed', 'rot90', 'square', 'place', 'lcm', 'ndfromtxt', 'isreal', 'partition', 'exp2', 'cosh', 'datetime_data', 'vander', 'fromiter', 'arcsinh', 'gradient', 'exp', 'column_stack', 'choose', 'floor', 'einsum_path', 'packbits', 'union1d', 'logaddexp2', 'geterrcall', 'who', 'blackman', 'log', 'msort', 'take_along_axis', 'lookfor', 'conjugate', 'argmin', 'rate', 'nancumsum', 'ndim', 'resize', 'info', 'mask_indices', 'ones_like', 'cross', 'asfarray', 'copyto', 'rollaxis', 'diag_indices', 'quantile', 'fliplr', 'ceil', 'meshgrid', 'fabs', 'identity', 'fastCopyAndTranspose', 'block', 'argwhere', 'greater_equal', 'nanargmax', 'mirr', 'frompyfunc', 'save', 'any', 'greater', 'format_float_scientific', 'right_shift', 'hypot', 'fix', 'log1p', 'median', 'gcd', 'nanargmin', 'get_printoptions', 'ediff1d', 'nested_iters', 'isscalar', 'is_busday', 'isclose', 'expand_dims', 'equal', 'float_power', 'flipud', 'get_array_wrap', 'where', 'polyder', 'spacing', 'issubdtype', 'asarray', 'atleast_2d', 'diagonal', 'result_type', 'asanyarray', 'tri', 'empty', 'maximum_sctype', 'require', 'nanpercentile', 'isnan', 'array_repr', 'diag_indices_from', 'bitwise_not', 'fv', 'issctype', 'var', 'modf', 'broadcast_arrays', 'fromfile',  ...
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
HW=pd.read_csv('data/gauss_R2.csv')

ax= HW.plot(kind='scatter',s=1.4,x="x",y="y");
x0,x1=xlim()
ax.plot([x0,x1],[0,0],'r');

# %% [markdown]
# ## Exercise 1: Put  𝑦−𝑥  in Dataframe

# %% [markdown]
# This first exercise's goal is to familarize you with the [pandas](http://pandas.pydata.org/pandas-docs/version/0.15.2/tutorials.html) package.
#
# Your task is to make a new column on the pandas dataframe `HW` where each element of the new column equals to $y-x$. Write a function **y_minus_x** that will create the new column, make sure the column's name is "y-x" . Notice that the function DOES NOT return any output, this is because the `HW` dataframe will be edited "in-place".
#
# <font  style="color:blue"> * **Code:** *</font>
# ```python
# print y_minus_x(HW)
# print HW.shape
# print HW.columns
# HW.head()
# ```
#
# <font  style="color:magenta"> * **Output:** *</font>
# ```
# None
# (1000, 3)
# Index([u'x', u'y', u'y-x'], dtype='object')
# ```
# <img src="data/reg_mean_pic.png"  style="width: 220px;"/>

# %%
def y_minus_x(HW):
    # input: the HW's dataset
    # output: there is NO OUTPUT
    # the new column column should be called 'y-x'
    
    # Your code

    HW["y-x"] = HW["y"] - HW["x"]

# %%
# Check Answer
HW=pd.read_csv('data/gauss_R2.csv')
assert y_minus_x(HW) == None 
assert HW.shape == (1000, 3)
assert all( HW.columns.values == array(['x', 'y', 'y-x']) )
assert sum(abs( array(HW["y-x"])[0:10] - \
               array([0.36236278,-2.37726552,-0.36501525,0.05449746,-0.27705517,1.80807383,-2.07001209,
                      -0.67536514,0.67519959,  0.97277652])   )) < 10**-5

# Create Graph
ax= HW.plot(kind='scatter',s=1.4,x="x",y="y-x",figsize=[10,8], title="Plot of y-x");

#
# AUTOGRADER TEST - DO NOT REMOVE
#
# Out:
# <ipython-input-9-9c5fc9195692>:5: DeprecationWarning: scipy.all is deprecated and will be removed in SciPy 2.0.0, use numpy.all instead
#   assert all( HW.columns.values == array(['x', 'y', 'y-x']) )
# <ipython-input-9-9c5fc9195692>:6: DeprecationWarning: scipy.sum is deprecated and will be removed in SciPy 2.0.0, use numpy.sum instead
#   assert sum(abs( array(HW["y-x"])[0:10] - \

# %% [markdown]
# Notice in the graph that there is a clear negative relationship between  𝑦−𝑥  and  𝑥 . As you might have guessed,  𝑦−𝑥  and  𝑥  are NOT independent.
#
# We can use linear regression to find the relationship between  𝑦−𝑥  and  𝑥  but before we do that, we can derive this mathematicaly. Remember from before, we showed:
# 𝑦=0+0⋅𝑥
#
# Now, we're doing linear regression to find:
# 𝑦−𝑥=𝑤0+𝑤1⋅𝑥
#
# ⟺𝑦=𝑤0+(1+𝑤1)⋅𝑥
#
# Comparing the two eqations for  𝑦 , you can deduce that  𝑤0=0  and  𝑤1=−1  . Now lets see how close our sampled data is to the true equation for the distribution!
#
#   Technical Note: The derivation is mathematically sound only because  𝑦−𝑥  is also a gaussian random variable. The sum of two gaussians is a gaussian. Under the laws of linear regression this ensures both the regressors of  𝑦  and  𝑦−𝑥  have zero expected error.

# %% [markdown]
# ## Exercise 2: Simple Linear Regression
#
# Write a function, **do_regression**, that performs linear regression to return
# $ \;
#  {\bf w} = \begin{pmatrix}
#  w_0\\
#  w_1
#  \end{pmatrix}
# $
# for the equation:
#
# $$
# \text{y-x}= w_0 + w_1 \cdot \text{x}
# $$
#
#
# <font  style="color:blue"> * **Code:** *</font>
# ```python
# w = do_regression(HW)
# print type(w)
# print w.shape
# ```
#
# <font  style="color:magenta"> * **Output:** *</font>
# ```
# <type 'numpy.ndarray'>
# (2,)
# ```

# %%
def f(x, reg):
    return reg[0]+ x*reg[1]

# %%
# modify this cell

def do_regression(HW):
    # input: the HW's dataset
    # output: a numpy array yielding w=(w0,w1) from linear regression
    
    # Your code
    # vstack merges a column containing only ones with x
    x = np.array(HW['x'])
    y = np.array(HW['y-x'])
    A = np.vstack([x, np.ones(len(x))]).T
    
    p,q = linalg.lstsq(A, y,rcond=None)[0]

    return np.array([q,p])

# %%
# Check Answer
w_hw = do_regression(HW)
assert str(type(w_hw)) == "<class 'numpy.ndarray'>"
assert w_hw.shape == (2,)
assert sum(abs(w_hw[0] - 0.02173387)) < 10**-5

# Plot Graph
print("LINEAR REGRESSION EQUATION:")
print("y-x = {:.2f} + {:.2f} x".format(w_hw[0],w_hw[1]))
ax= HW.plot(kind='scatter',s=1.4,x="x",y="y-x",figsize=[10,8]);
x0,x1=xlim()
ax.plot([x0,x1],[f(x0,w_hw),f(x1,w_hw)],'k');

#
# AUTOGRADER TEST - DO NOT REMOVE
#
# Out:
# LINEAR REGRESSION EQUATION:
# y-x = 0.02 + -1.01 x
# <ipython-input-20-ba1cd0ca6e17>:5: DeprecationWarning: scipy.sum is deprecated and will be removed in SciPy 2.0.0, use numpy.sum instead
#   assert sum(abs(w_hw[0] - 0.02173387)) < 10**-5
